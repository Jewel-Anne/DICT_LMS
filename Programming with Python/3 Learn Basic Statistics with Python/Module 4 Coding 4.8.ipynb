# %% [markdown]
# ## 4.8 Coding Exercises
#
# ![image.png](attachment:96a3ea87-dc9f-4067-aba0-30b8edebe31f.png)
#
# ![image.png](attachment:22f080a9-6a18-4dfc-ab35-c136b57ec3b7.png)

# %% [markdown]
# ### From East Asia Population_Coding Exercises
# Module 4 Coding 4.4.ipynb

# %%
import pandas as pd
df = pd.read_csv("population_by_country_2020.csv")
filter = df[df["Country"].isin(["China", "South Korea", "North Korea", "Macau", "Hong Kong", "Tibet", "Taiwan", "Japan", "Mongolia"])]
stat_summary = filter.describe()
stat_summary
# Out:
#        Population (2020)    Net Change  Density (P/Km²)  Land Area (Km²)  \
# count       7.000000e+00  7.000000e+00         7.000000     7.000000e+00
# mean        2.397714e+08  7.813759e+05      1293.714286     1.651489e+06
# std         5.310264e+08  2.105116e+06      2587.920640     3.454906e+06
# min         3.287242e+06 -3.838400e+05         2.000000     1.050000e+03
# 25%         1.566595e+07  4.338800e+04       183.500000     6.632000e+04
# 50%         2.579859e+07  5.312300e+04       347.000000     1.204100e+05
# 75%         8.884220e+07  8.674100e+04       600.000000     9.590575e+05
# max         1.440298e+09  5.540090e+06      7140.000000     9.388211e+06
#
#        Migrants (net)
# count        7.000000
# mean    -30293.428571
# std     142598.157794
# min    -348399.000000
# 25%      -3127.500000
# 50%      11731.000000
# 75%      29654.500000
# max      71560.000000

# %% [markdown]
# ### 4.8 Coding Exercise

# %%
import matplotlib.pyplot as plt

# %%
country = filter["Country"]
population = filter["Population (2020)"]

# %%
fig = plt.figure(figsize=(16,10))

# %%
plt.barh(country, population)
plt.show()

# %%
plt.barh(country, population)
plt.title("2020 Population by Country (East Asia)", loc="center")

plt.show()

# %% [markdown]
# #### DICT LMS Solution
#
# ![image.png](attachment:81ef6f08-ad53-4ee4-b84e-2d373544d4a4.png)
#
# ![image.png](attachment:5fda16f8-ff0f-4794-a2fc-064e1d05e8cb.png)
