# %% [markdown]
# # 3.4 Coding Exercises
#
# ![image.png](attachment:013af303-1b33-4d80-acac-662a23cf3e36.png)
#
# ![image.png](attachment:3f27829b-ec62-43ef-8ec9-464ba2240978.png)

# %% [markdown]
# ## Coding Exercises

# %%
import pandas as pd

# %%
author = pd.Series(['E.L. James', 'Suzanne Collins', 'J.K. Rowling', 'Dan Brown'])
reviews = pd.Series([410, 211, 314, 178])

print(author)
print(reviews)
# Out:
# 0         E.L. James
# 1    Suzanne Collins
# 2       J.K. Rowling
# 3          Dan Brown
# dtype: object
# 0    410
# 1    211
# 2    314
# 3    178
# dtype: int64

# %%
dframe = {'Author': ['E.L. James', 'Suzanne Collins', 'J.K. Rowling', 'Dan Brown'],
          'Reviews': [410, 211, 314, 178]}
dataframe = pd.DataFrame(dframe)
dataframe
# Out:
#             Author  Reviews
# 0       E.L. James      410
# 1  Suzanne Collins      211
# 2     J.K. Rowling      314
# 3        Dan Brown      178

# %%
bestsell = pd.read_csv('bestsellers.csv')
bestsell.head()
# Out:
#                                       Name              Author  User Rating  \
# 0            10-Day Green Smoothie Cleanse            JJ Smith          4.7
# 1                                      NaN                 NaN          NaN
# 2                        11/22/63: A Novel        Stephen King          4.6
# 3  12 Rules for Life: An Antidote to Chaos  Jordan B. Peterson          4.7
# 4                   1984 (Signet Classics)       George Orwell          4.7
#
#    Reviews  Price    Year        Genre         Type
# 0  17350.0    8.0  2016.0  Non Fiction  Non Fiction
# 1      NaN    NaN     NaN          NaN          NaN
# 2   2052.0   22.0  2011.0      Fiction      Fiction
# 3  18979.0   15.0  2018.0  Non Fiction  Non Fiction
# 4  21424.0    6.0  2017.0      Fiction      Fiction

# %%
bestsell.info()
bestsell.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 375 entries, 0 to 374
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         347 non-null    object
#  1   Author       347 non-null    object
#  2   User Rating  347 non-null    float64
#  3   Reviews      347 non-null    float64
#  4   Price        347 non-null    float64
#  5   Year         347 non-null    float64
#  6   Genre        347 non-null    object
#  7   Type         347 non-null    object
# dtypes: float64(4), object(4)
# memory usage: 23.6+ KB
# (375, 8)

# %% [markdown]
# ### DICT LMS Solution
#
# ![image.png](attachment:b83ba4c1-599b-4b9d-847d-541013357dfc.png)
#
# ![image.png](attachment:e52bdf34-d701-49cd-aa91-f5506e4f2147.png)
#
# ![image.png](attachment:1c12cd1a-536e-4999-8b5f-c283fb7ef54a.png)
#
# ![image.png](attachment:014cde03-381a-4ffd-a785-7d5850d2d4fb.png)
#
# ![image.png](attachment:47c9eb4a-2d25-4ed1-a597-5e549f766c7b.png)
#
# ![image.png](attachment:b2883b0f-98b6-4c69-a01b-986ea15e6442.png)
